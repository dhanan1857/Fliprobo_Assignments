# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os

# %%
os.chdir("/content/drive/My Drive/Colab Notebooks")

# %%
df=pd.read_csv("/content/drive/My Drive/malignant_train.csv")

# %%
df_test=pd.read_csv("/content/drive/My Drive/Malignant_test.csv")

# %%
df.shape,df_test.shape
# Out:
# ((159571, 8), (153164, 2))

# %%
df.head()
# Out:
#                  id  ... loathe
# 0  0000997932d777bf  ...      0
# 1  000103f0d9cfb60f  ...      0
# 2  000113f07ec002fd  ...      0
# 3  0001b41b1c6bb37e  ...      0
# 4  0001d958c54c6e35  ...      0
#
# [5 rows x 8 columns]

# %%
df_test.head(5)
# Out:
#                  id                                       comment_text
# 0  00001cee341fdb12  Yo bitch Ja Rule is more succesful then you'll...
# 1  0000247867823ef7  == From RfC == \n\n The title is fine as it is...
# 2  00013b17ad220c46  " \n\n == Sources == \n\n * Zawe Ashton on Lap...
# 3  00017563c3f7919a  :If you have a look back at the source, the in...
# 4  00017695ad8997eb          I don't anonymously edit articles at all.

# %%
df['comment_text']
# Out:
# 0         Explanation\nWhy the edits made under my usern...
# 1         D'aww! He matches this background colour I'm s...
# 2         Hey man, I'm really not trying to edit war. It...
# 3         "\nMore\nI can't make any real suggestions on ...
# 4         You, sir, are my hero. Any chance you remember...
#                                 ...
# 159566    ":::::And for the second time of asking, when ...
# 159567    You should be ashamed of yourself \n\nThat is ...
# 159568    Spitzer \n\nUmm, theres no actual article for ...
# 159569    And it looks like it was actually you who put ...
# 159570    "\nAnd ... I really don't think you understand...
# Name: comment_text, Length: 159571, dtype: object

# %%
df_test['comment_text']
# Out:
# 0         Yo bitch Ja Rule is more succesful then you'll...
# 1         == From RfC == \n\n The title is fine as it is...
# 2         " \n\n == Sources == \n\n * Zawe Ashton on Lap...
# 3         :If you have a look back at the source, the in...
# 4                 I don't anonymously edit articles at all.
#                                 ...
# 153159    . \n i totally agree, this stuff is nothing bu...
# 153160    == Throw from out field to home plate. == \n\n...
# 153161    " \n\n == Okinotorishima categories == \n\n I ...
# 153162    " \n\n == ""One of the founding nations of the...
# 153163    " \n :::Stop already. Your bullshit is not wel...
# Name: comment_text, Length: 153164, dtype: object

# %%
# remove punctuation from comments_text column
# Convert all comments_text to lower case

# %%
df['comment_text']=df['comment_text'].str.lower()

# %%
df_test['comment_text']=df_test['comment_text'].str.lower()

# %%
# Remove punctuation
df['comment_text'] = df['comment_text'].str.replace(r'[^\w\d\s]', ' ')

# %%
df_test['comment_text'] = df_test['comment_text'].str.replace(r'[^\w\d\s]', ' ')

# %%
# Replace whitespace between terms with a single space
df['comment_text'] = df['comment_text'].str.replace(r'\s+', ' ')
df_test['comment_text'] = df_test['comment_text'].str.replace(r'\s+', ' ')

# %%
# Remove leading and trailing whitespace
df['comment_text'] = df['comment_text'].str.replace(r'^\s+|\s+?$', '')
df_test['comment_text'] = df_test['comment_text'].str.replace(r'^\s+|\s+?$', '')

# %%
# remove stopwords from comments_text
import string
import nltk
from nltk.corpus import  stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop_words = set(stopwords.words('english') + ['u', 'ü', 'ur', '4', '2', 'im', 'dont', 'doin', 'ure'])

# %%
df['comments without stopwords'] = df['comment_text'].apply(lambda x: ' '.join(
    term for term in x.split() if term not in stop_words))

# %%
df_test['comments without stopwords'] = df_test['comment_text'].apply(lambda x: ' '.join(
    term for term in x.split() if term not in stop_words))

# %%
df.head(5)
# Out:
#                  id  ...                         comments without stopwords
# 0  0000997932d777bf  ...  explanation edits made username hardcore metal...
# 1  000103f0d9cfb60f  ...  aww matches background colour seemingly stuck ...
# 2  000113f07ec002fd  ...  hey man really trying edit war guy constantly ...
# 3  0001b41b1c6bb37e  ...  make real suggestions improvement wondered sec...
# 4  0001d958c54c6e35  ...                      sir hero chance remember page
#
# [5 rows x 9 columns]

# %%
# Lemmatization - From plural to single + Base form of a word (example better-> good)
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
df.columns
# Out:
# Index(['id', 'comment_text', 'malignant', 'highly_malignant', 'rude', 'threat',
#        'abuse', 'loathe', 'comments without stopwords'],
#       dtype='object')

# %%
lemma_word=[]
for word in df['comments without stopwords']:
  word=WordNetLemmatizer().lemmatize(word)
  lemma_word.append(word)

# %%
lemma_word
# Out:
# ['explanation edits made username hardcore metallica fan reverted vandalisms closure gas voted new york dolls fac please remove template talk page since retired 89 205 38 27',
#  'aww matches background colour seemingly stuck thanks talk 21 51 january 11 2016 utc',
#  'hey man really trying edit war guy constantly removing relevant information talking edits instead talk page seems care formatting actual info',
#  'make real suggestions improvement wondered section statistics later subsection types accidents think references may need tidying exact format ie date format etc later one else first preferences formatting style references want please let know appears backlog articles review guess may delay reviewer turns listed relevant form eg wikipedia good_article_nominations transport',
#  'sir hero chance remember page',
#  'congratulations well use tools well talk',
#  'cocksucker piss around work',
#  'vandalism matt shirvington article reverted please banned',
# ...

# %%
lemma_word_test=[]
for word in df_test['comments without stopwords']:
  word=WordNetLemmatizer().lemmatize(word)
  lemma_word_test.append(word)

# %%
lemma_word_test
# Out:
# ['yo bitch ja rule succesful ever whats hating sad mofuckas bitch slap pethedic white faces get kiss ass guys sicken ja rule pride da music man diss shit nothin wrong bein like tupac brother fuckin white boys get things right next time',
#  'rfc title fine imo',
#  'sources zawe ashton lapland',
#  'look back source information updated correct form guess source updated shall update information thank message',
#  'anonymously edit articles',
#  'thank understanding think highly would revert without discussion',
#  'please add nonsense wikipedia edits considered vandalism quickly undone would like experiment please use sandbox instead thank',
#  'dear god site horrible',
# ...

# %%
df.head()
# Out:
#                  id  ...                         comments without stopwords
# 0  0000997932d777bf  ...  explanation edits made username hardcore metal...
# 1  000103f0d9cfb60f  ...  aww matches background colour seemingly stuck ...
# 2  000113f07ec002fd  ...  hey man really trying edit war guy constantly ...
# 3  0001b41b1c6bb37e  ...  make real suggestions improvement wondered sec...
# 4  0001d958c54c6e35  ...                      sir hero chance remember page
#
# [5 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# id                            0
# comment_text                  0
# malignant                     0
# highly_malignant              0
# rude                          0
# threat                        0
# abuse                         0
# loathe                        0
# comments without stopwords    0
# dtype: int64

# %%
3 #Checking ull value
df_test.isnull().sum()
# Out:
# id                            0
# comment_text                  0
# comments without stopwords    0
# dtype: int64

# %%
# Feature Engineering
#Any column taken below which has value 1 means the comments indicates hatred .
df['hate_comments']=df['malignant']+df['highly_malignant']+df['rude']+df['threat']+df['abuse']+df['loathe']

# %%
df.head(15)
# Out:
#                   id  ... hate_comments
# 0   0000997932d777bf  ...             0
# 1   000103f0d9cfb60f  ...             0
# 2   000113f07ec002fd  ...             0
# 3   0001b41b1c6bb37e  ...             0
# 4   0001d958c54c6e35  ...             0
# 5   00025465d4725e87  ...             0
# 6   0002bcb3da6cb337  ...             4
# 7   00031b1e95af7921  ...             0
# 8   00037261f536c51d  ...             0
# 9   00040093b2687caa  ...             0
# 10  0005300084f90edc  ...             0
# 11  00054a5e18b50dd4  ...             0
# 12  0005c987bdfc9d4b  ...             1
# 13  0006f16e4e9f292e  ...             0
# 14  00070ef96486d6f9  ...             0
#
# [15 rows x 10 columns]

# %%
# Convering response in 0 and 1 where 0 means no and 1 means yes
df['hate_comments'] = [0 if x ==0 else 1 for x in df['hate_comments']]

# %%
df.head(15)
# Out:
#                   id  ... hate_comments
# 0   0000997932d777bf  ...             0
# 1   000103f0d9cfb60f  ...             0
# 2   000113f07ec002fd  ...             0
# 3   0001b41b1c6bb37e  ...             0
# 4   0001d958c54c6e35  ...             0
# 5   00025465d4725e87  ...             0
# 6   0002bcb3da6cb337  ...             1
# 7   00031b1e95af7921  ...             0
# 8   00037261f536c51d  ...             0
# 9   00040093b2687caa  ...             0
# 10  0005300084f90edc  ...             0
# 11  00054a5e18b50dd4  ...             0
# 12  0005c987bdfc9d4b  ...             1
# 13  0006f16e4e9f292e  ...             0
# 14  00070ef96486d6f9  ...             0
#
# [15 rows x 10 columns]

# %%
# we can drop columns - malignant,highly_malignant,rude,threat,abuse,loathe and comment_text
for col in ['malignant','highly_malignant','rude','threat','abuse','loathe']:
    df.drop([col],1,inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'comment_text', 'comments without stopwords', 'hate_comments'], dtype='object')

# %%
# drop column comment_text
df.drop(['comment_text'],1,inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'comments without stopwords', 'hate_comments'], dtype='object')

# %%
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
sia = SentimentIntensityAnalyzer()

# %%
df.head(5)
# Out:
#                  id  ... hate_comments
# 0  0000997932d777bf  ...             0
# 1  000103f0d9cfb60f  ...             0
# 2  000113f07ec002fd  ...             0
# 3  0001b41b1c6bb37e  ...             0
# 4  0001d958c54c6e35  ...             0
#
# [5 rows x 3 columns]

# %%
# Tokenizing the columns "comments without stopwords"
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import word_tokenize

# %%
df['tokenized_text'] = df.apply(lambda row: nltk.word_tokenize(row['comments without stopwords']), axis=1)

# %%
df.columns
# Out:
# Index(['id', 'comments without stopwords', 'hate_comments', 'tokenized_text'], dtype='object')

# %%
df.head(5)
# Out:
#                  id  ...                                     tokenized_text
# 0  0000997932d777bf  ...  [explanation, edits, made, username, hardcore,...
# 1  000103f0d9cfb60f  ...  [aww, matches, background, colour, seemingly, ...
# 2  000113f07ec002fd  ...  [hey, man, really, trying, edit, war, guy, con...
# 3  0001b41b1c6bb37e  ...  [make, real, suggestions, improvement, wondere...
# 4  0001d958c54c6e35  ...                [sir, hero, chance, remember, page]
#
# [5 rows x 4 columns]

# %%
df['tokenized_text']
# Out:
# 0         [explanation, edits, made, username, hardcore,...
# 1         [aww, matches, background, colour, seemingly, ...
# 2         [hey, man, really, trying, edit, war, guy, con...
# 3         [make, real, suggestions, improvement, wondere...
# 4                       [sir, hero, chance, remember, page]
#                                 ...
# 159566    [second, time, asking, view, completely, contr...
# 159567    [ashamed, horrible, thing, put, talk, page, 12...
# 159568    [spitzer, umm, theres, actual, article, prosti...
# 159569    [looks, like, actually, put, speedy, first, ve...
# 159570    [really, think, understand, came, idea, bad, r...
# Name: tokenized_text, Length: 159571, dtype: object
